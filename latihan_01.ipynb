# %%
# menghitung jumlah detik dalam sehari
jumlah = 24

# %%
# menghitung jumlah detik dalam sehari
jumlah = 24 * 60 * 60
print(jumlah)
# Out:
# 86400

# %%
# menghitung rumus persegi panjang
panjang = 10
lebar = 5
luas = panjang * lebar
print(luas)
# Out:
# 50

# %%
nama_mhs1 = "Andi"
nama_mhs2 = "Budi"
print(nama_mhs1, "dan", nama_mhs2, "adalah mahasiswa fakultas FTI")
# Out:
# Andi dan Budi adalah mahasiswa fakultas FTI
