# %%
# Mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: Menampilkan data dari csv
import pandas as pd

# Read the CSV file into a Pandas DataFrame.
df = pd.read_csv('/content/drive/My Drive/Latihan Machine Learning/fakultas.csv')

# Print the DataFrame.
print(df)
# Out:
#    No       Nama Fakultas                         Program Studi
# 0   1  Teknologi Industri  Teknologi Rekayasa Komputer Jaringan
# 1   2  Teknologi Industri  Teknologi Rekayasa Energi Terbarukan
# 2   3  Teknologi Industri                       Teknik Industri
# 3   4  Teknologi Industri                        Teknik Elektro
# 4   5  Teknologi Industri                          Teknik Kimia
# 5   6  Teknologi Industri                          Teknik Mesin

# %%
# prompt: buatkan script untuk menghitung luas persegi panjang

from google.colab import drive
# Mounting drive
drive.mount('/content/drive')

# Define function to calculate area of a rectangle
def area_rectangle(length, width):
  """
  This function calculates the area of a rectangle.

  Args:
    length: The length of the rectangle.
    width: The width of the rectangle.

  Returns:
    The area of the rectangle.
  """
  area = length * width
  return area

# Get length and width from user
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

# Calculate and print the area
area = area_rectangle(length, width)
print("The area of the rectangle is:", area)
